# %%
df = pd.read_excel('../data/raw/online_retail_II.xlsx', sheet_name = 'Sheet1')
print("Shape:", df.shape)

# %%
df.columns.to_list()
# Out:
# ['Invoice',
#  'StockCode',
#  'Description',
#  'Quantity',
#  'InvoiceDate',
#  'Price',
#  'Customer ID',
#  'Country']

# %%
df.duplicated().sum()
# Out:
# 6865
